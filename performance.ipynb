# %%
import numpy as np
import os
import librosa
import librosa.display
from matplotlib import pyplot as plt
import IPython.display as ipd
from skimage.feature import peak_local_max
from scipy import ndimage, misc
import datetime

# %%
widths = [100, 75, 50, 25]
precision = [31.7, 47.5, 69.2, 80.9]
plt.bar([0,1,2,3], precision, tick_label = widths)
plt.xlabel("Neighborhood Width (frames)")
plt.ylabel("Average Precision %")
plt.title("Precision of Neighborhood Widths")
# Out:
# Text(0.5, 1.0, 'Precision of Neighborhood Widths')

# %%
precision = [74.6, 69.2, 53.5, 60.4, 26.4]
plt.bar([0,1,2,3,4],precision, tick_label = ("1024.256", "1024.512", "512.256", "512.128", "256.128"))
plt.xlabel("Window and Hop Sizes")
plt.ylabel("Average Precision %")
plt.title("Precision at Various STFT Settings")
# Out:
# Text(0.5, 1.0, 'Precision at Various STFT Settings')

# %%
target_size = [25, 50, 75, 100]
precision = [69.8, 79.7, 81.1, 82.6]
plt.bar([0,1,2,3],precision, tick_label = target_size)
plt.xlabel("Target Zone Width")
plt.ylabel("Average Precision %")
plt.title("Precision at Various Target Zone Widths")
plt.ylim([50,100])
# Out:
# (50.0, 100.0)

# %%
params = ["25.25.50.50", "25.25.75.75", "25.25.100.100", "30.20.50.70"]
precision = [3.75, 7.0, 21.0, 5.25]
plt.bar([0,1,2,3],precision, tick_label = params)
plt.xlabel("Neighbor and Target Zone Widths")
plt.ylabel("Computation Time per Query (sec)")
plt.title("Computation Times of Width Settings")
# Out:
# Text(0.5, 1.0, 'Computation Times of Width Settings')

# %%
params = ["25.25.50.50", "25.25.75.75", "25.25.100.100", "30.20.50.70"]
precision = [79.7, 81.1, 82.5, 81.4]
plt.bar([0,1,2,3],precision, tick_label = params)
plt.xlabel("Neighbor and Target Zone Widths")
plt.ylabel("Average Precision %")
plt.title("Precision of Width Settings")
plt.ylim([70,85])
# Out:
# (70.0, 85.0)
